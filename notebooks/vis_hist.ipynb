# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import sys

sys.path.append("../")

# %%
import json
with open("../ppo_from_scratch_metrics.json") as f:
    so3_metrics = json.loads(f.read())

# %%
plt.plot(so3_metrics["success_rate"])

# %%
so3_metrics.keys()
# Out:
# dict_keys(['episode_rewards', 'episode_lengths', 'success_rate', 'collision_rate', 'mean_shaped_reward', 'policy_loss', 'value_loss', 'entropy', 'approx_kl'])

# %%
plt.plot(so3_metrics["episode_rewards"])
